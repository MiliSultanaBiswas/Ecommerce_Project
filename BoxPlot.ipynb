# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Excel file into a DataFrame
excel_file = 'Data Analysis - Caselet#2.xlsx'

df = pd.read_excel(excel_file,sheet_name='DifferentFormat')

# Iterate over each column and create a box plot

plt.figure(figsize=(10, 6))
df.boxplot(column='TPT',by='Team Member')
plt.title(f'Box Plot for {column}')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h1>Observation</h1>

# %% [markdown]
# Excel file into a DataFrame and then generate individual box plots for each column in the DataFrame.Here if you see the median of the box plot
# Wasim's performence is very good then good performance of Vinay as well as Vimal and Dhanya and Aniket.  And lowest performence is Arohi and Anushka .
